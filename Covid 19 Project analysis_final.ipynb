# %%
import pandas as pd

# %%
df= pd.read_csv('covid_19_india_state wise.csv')

# %%
df.head()
# Out:
#          State/Union Territory  ConfirmedIndianNational  \
# 0  Andaman and Nicobar Islands                        8
# 1               Andhra Pradesh                       81
# 2                        Bihar                       32
# 3                   Chandigarh                       50
# 4                 Chhattisgarh                       25
#
#    ConfirmedForeignNational  Cured   Deaths  Total Cases
# 0                         0      0        0            8
# 1                         0      6        0           81
# 2                         0      0        9           32
# 3                         0      0        0           50
# 4                         0      0        0           25

# %%
df['Total Cases'].sum()
# Out:
# 6103

# %%
pip install folium
# Out:
# ...
#      |████████████████████████████████| 93 kB 1.2 MB/s eta 0:00:011
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df['Active cases']= df['Total Cases']-(df[' Deaths']+df['Cured'])

# %%
df.head()
# Out:
#          State/Union Territory  ConfirmedIndianNational  \
# 0  Andaman and Nicobar Islands                        8
# 1               Andhra Pradesh                       81
# 2                        Bihar                       32
# 3                   Chandigarh                       50
# 4                 Chhattisgarh                       25
#
#    ConfirmedForeignNational  Cured   Deaths  Total Cases  Active cases
# 0                         0      0        0            8             8
# 1                         0      6        0           81            75
# 2                         0      0        9           32            23
# 3                         0      0        0           50            50
# 4                         0      0        0           25            25

# %%
df.style.background_gradient(cmap="Reds")
# Out:
# <style  type="text/css" >
#     #T_e56a56e0_ce81_11ea_9ab3_4ebb6431e715row0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_e56a56e0_ce81_11ea_9ab3_4ebb6431e715row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_e56a56e0_ce81_11ea_9ab3_4ebb6431e715row0_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_e56a56e0_ce81_11ea_9ab3_4ebb6431e715row0_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_e56a56e0_ce81_11ea_9ab3_4ebb6431e715row0_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_e56a56e0_ce81_11ea_9ab3_4ebb6431e715row0_col6 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_e56a56e0_ce81_11ea_9ab3_4ebb6431e715row1_col1 {
#             background-color:  #feeae0;
#             color:  #000000;
# ...

# %%
Total_Active_cases=df.groupby('State/Union Territory')['Active cases'].sum().sort_values(ascending=False).to_frame()

# %%
Total_Active_cases
# Out:
#                              Active cases
# State/Union Territory
# Kerala                               1025
# Maharashtra                          1015
# Rajasthan                             382
# Karnataka                             349
# Uttar Pradesh                         334
# Telengana                             325
# Haryana                               286
# Delhi                                 270
# Gujarat                               235
# Punjab                                216
# Ladakh                                150
# Tamil Nadu                            140
# Madhya Pradesh                         96
# Jammu and Kashmir                      82
# Andhra Pradesh                         75
# West Bengal                            64
# Chandigarh                             50
# Uttarakhand                            36
# Chhattisgarh                           25
# Odisha                                 23
# Bihar                                  23
# ...

# %%
Total_Active_cases.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_e9335b50_ce81_11ea_9ab3_4ebb6431e715row0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e9335b50_ce81_11ea_9ab3_4ebb6431e715row1_col0 {
#             background-color:  #6b010e;
#             color:  #f1f1f1;
#         }    #T_e9335b50_ce81_11ea_9ab3_4ebb6431e715row2_col0 {
#             background-color:  #fc9474;
#             color:  #000000;
#         }    #T_e9335b50_ce81_11ea_9ab3_4ebb6431e715row3_col0 {
#             background-color:  #fc9e80;
#             color:  #000000;
#         }    #T_e9335b50_ce81_11ea_9ab3_4ebb6431e715row4_col0 {
#             background-color:  #fca486;
#             color:  #000000;
#         }    #T_e9335b50_ce81_11ea_9ab3_4ebb6431e715row5_col0 {
#             background-color:  #fca689;
#             color:  #000000;
#         }    #T_e9335b50_ce81_11ea_9ab3_4ebb6431e715row6_col0 {
#             background-color:  #fcb398;
#             color:  #000000;
# ...

# %%
df.plot(kind='bar',x='State/Union Territory',y='Total Cases')
plt.show()

# %%
df.plot(kind='bar',x='State/Union Territory',y='Total Cases')
plt.show()

# %%
plt.bar(df['State/Union Territory'],df['Total Cases'])
# Out:
# <BarContainer object of 27 artists>

# %%
df.plot(kind='scatter',x='State/Union Territory',y='Total Cases')

# %%
plt.scatter
# Out:
# <function matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=<deprecated parameter>, edgecolors=None, *, plotnonfinite=False, data=None, **kwargs)>

# %%
plt.scatter(df['State/Union Territory'],df['Total Cases'])

# %%
fig=plt.figure(figsize=(20,10),dpi=200)
axes=fig.add_axes([0,0,1,1])
axes.bar(df['State/Union Territory'],df['Total Cases'])
axes.set_title("Total Cases in India")
axes.set_xlabel("State/Union Territory")
axes.set_ylabel('Total Cases')
plt.show()

# %%
india_cord=pd.read_csv('India coordinates.csv')

# %%
india_cord
# Out:
#    State/Union Territory   Latitude  Longitude
# 0             Chandigarh  17.874857  78.100815
# 1           Chhattisgarh  21.295132  81.828232
# 2                Gujarat  22.309425  72.136230
# 3                Haryana  29.238478  76.431885
# 4       Himachal Pradesh  32.084206  77.571167
# 5              Karnataka  15.317277  75.713890
# 6                 Kerala  10.850516  76.271080
# 7         Madhya Pradesh  23.473324  77.947998
# 8            Maharashtra  19.601194  75.552979
# 9                 Odisha  20.940920  84.803467
# 10             Rajasthan  27.391277  73.432617
# 11            Tamil Nadu  11.059821  78.387451
# 12             Telengana  17.123184  79.208824
# 13         Uttar Pradesh  28.207609  79.826660
# 14           Uttarakhand  28.207609  79.826660
# 15           West Bengal  22.978624  87.747803

# %%
df_full=pd.merge(india_cord,df,on='State/Union Territory')

# %%
df_full
# Out:
#    State/Union Territory   Latitude  Longitude  ConfirmedIndianNational  \
# 0             Chandigarh  17.874857  78.100815                       50
# 1           Chhattisgarh  21.295132  81.828232                       25
# 2                Gujarat  22.309425  72.136230                      256
# 3                Haryana  29.238478  76.431885                      111
# 4       Himachal Pradesh  32.084206  77.571167                       21
# 5              Karnataka  15.317277  75.713890                      405
# 6                 Kerala  10.850516  76.271080                     1091
# 7         Madhya Pradesh  23.473324  77.947998                      105
# 8            Maharashtra  19.601194  75.552979                     1111
# 9                 Odisha  20.940920  84.803467                       23
# 10             Rajasthan  27.391277  73.432617                      296
# 11            Tamil Nadu  11.059821  78.387451                      138
# ...

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
 pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
map=folium.Map(location=[20,70],zoom_start=4,tiles='stamenterrain')
for lat,long,value, name in zip(df_full['Latitude'],df_full['Longitude'],df_full['Total Cases'],df_full['State/Union Territory']):
               folium.CircleMarker([lat,long],radius=10,popup=('<strong>State</strong>:'+str(name).capitalize()+'<br>''<strong>Total Cases</strong>:'+str(value)+'<br'),color='red',full_color='red',fill_opacity=0.3).add_to(map)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-ca3327e45ae4> in <module>
# ----> 1 map=folium.Map(location=[20,70],zoom_start=4,tiles='stamenterrain')
#       2 for lat,long,value, name in zip(df_full['Latitude'],df_full['Longitude'],df_full['Total Cases'],df_full['State/Union Territory']):
#       3                folium.CircleMarker([lat,long],radius=10,popup=('<strong>State</strong>:'+str(name).capitalize()+'<br>''<strong>Total Cases</strong>:'+str(value)+'<br'),color='red',full_color='red',fill_opacity=0.3).add_to(map)
#
# NameError: name 'folium' is not defined

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
